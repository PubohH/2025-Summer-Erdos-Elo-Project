# %%
import pandas as pd
import numpy as np

# %%
matches = pd.read_csv('/Users/tliu/Desktop/Erdos Project/Data/matches.csv')

# %%
matches.head()
# Out:
#         player1         player2  score1  score2  best_of  tournament_id date  \
# 0  Colin Roscoe      Jackie Rea       9       6       17            753  NaN
# 1  Tommy Murphy   Clive Everton       9       4       17            753  NaN
# 2    Vic Harris     Marcus Owen       9       4       17            753  NaN
# 3    Bob Harris  Graham Cripsey       9       6       17            753  NaN
# 4  Geoff Foulds     Matt Gibson       9       3       17            753  NaN
#
#    year
# 0  1982
# 1  1982
# 2  1982
# 3  1982
# 4  1982

# %%
from elo_v3 import elo_rating
elo = elo_rating()

# %%
elo.update_stats(matches = matches, K_factor = 6, ratio = 0.1)
# Out:
# /Users/tliu/Desktop/Erdos Project/Elo Rating/elo_v3/elo_v3.py:120: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.stats_by_years.fillna(0, inplace = True)
#                  elo_rating  matches_played  matches_won  matches_win_rate  \
# A Barrett               992               1            0          0.000000
# A Bulajiang             977               8            1          0.125000
# A Chan                  999               2            1          0.500000
# A Coleman               989               1            0          0.000000
# A Noad                  992               1            0          0.000000
# ...                     ...             ...          ...               ...
# ...

# %%
stats = elo.stats
stats.sort_values(by = ['elo_rating'], ascending=False).head(20)
# Out:
#                    elo_rating  matches_played  matches_won  matches_win_rate  \
# Judd Trump               2121            1534         1106          0.720991
# Kyren Wilson             2057            1122          721          0.642602
# Ronnie O'Sullivan        2040            1555         1181          0.759486
# Zhao Xintong             2035             375          223          0.594667
# John Higgins             2035            1933         1363          0.705122
# Mark Williams            1950            1835         1201          0.654496
# Mark Selby               1948            1640         1121          0.683537
# Yan Bingtao              1900             354          232          0.655367
# Shaun Murphy             1898            1413          927          0.656051
# Neil Robertson           1881            1331          883          0.663411
# Ding Junhui              1876            1033          685          0.663117
# ...

# %%
players_ranked = stats.sort_values(by = ['elo_rating'], ascending=False).index

# %%
stats_by_years = elo.stats_by_years
stats_by_years.loc[players_ranked]
# Out:
#                    matches_played_3_years  matches_won_3_years  \
# Judd Trump                            212                  168
# Kyren Wilson                          218                  147
# Ronnie O'Sullivan                     101                   73
# Zhao Xintong                           16                   15
# John Higgins                          190                  131
# ...                                   ...                  ...
# Dennis Hughes                           0                    0
# Jack Fitzmaurice                        0                    0
# Bert Demarco                            0                    0
# Bernard Bennett                         0                    0
# Clive Everton                           0                    0
#
#                    matches_played_1_year  matches_won_1_year  \
# Judd Trump                            44                  32
# Kyren Wilson                          39                  28
# ...

# %%
rate = stats.sort_values(by = ['elo_rating'], ascending=False)['elo_rating']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(rate)

# %%
1/(1+np.exp(-250/400))
# Out:
# np.float64(0.6513548646660542)
