# %% [markdown]
# In the match data generated in data_generation.ipynb, player1 is always the winner. For the purpose of future data exploration and modeling, we exchange player1 and player2 for half of the matches and save it in another csv file.

# %%
import pandas as pd
import numpy as np
import random

# %%
data = pd.read_csv('match_data_20_tourns.csv')

# %%
data.head()
# Out:
#                  player1          player2  best_of  elo_match_win_rate  \
# 0           Long Zehuang    Haydon Pinhey        7            0.719210
# 1            Wang Yuchen    Andrew Pagett        7            0.500000
# 2       Daniel Womersley      Ben Mertens        7            0.300556
# 3            Jimmy White    Paul Deaville        7            0.561265
# 4  Alexander Ursenbacher  Mostafa Dorgham        7            0.821305
#
#    elo_frame_win_rate  p1_matches_played  p1_matches_won  p1_frames_played  \
# 0            0.604679                 78              39               443
# 1            0.500000                100              37               626
# 2            0.405524                109              53               551
# 3            0.528095               1577             844             13093
# 4            0.663180                286             129              1728
#
#    p1_frames_won  p2_matches_played  ...  p1_frames_played_1_year  \
# 0            225                115  ...                      178
# 1            268                352  ...                       74
# 2            266                107  ...                       86
# 3           6755                 32  ...                       85
# 4            829                 25  ...                      113
#
#    p1_frames_won_1_year  p1_frames_played_3_years  p1_frames_won_3_years  \
# 0                    99                       284                    147
# 1                    38                       158                     89
# 2                    40                       180                     89
# 3                    31                       384                    153
# 4                    56                       400                    196
#
#    p2_frames_played_1_year  p2_frames_won_1_year  p2_frames_played_3_years  \
# 0                      121                    57                       347
# 1                      144                    65                       417
# 2                      136                    67                       471
# 3                       97                    51                       126
# 4                      108                    41                       154
#
#    p2_frames_won_3_years  match_result  win_percentage
# 0                    168           0.0        0.571429
# 1                    170           0.0        0.800000
# 2                    240           0.0        0.800000
# 3                     66           0.0        0.571429
# 4                     53           0.0        0.800000
#
# [5 rows x 23 columns]

# %%
row = data.loc[0]

# %%
#We use random.shuffle to choose the indices of matches we want to modify.
match_index = list(range(len(data)))
random.shuffle(match_index)
modify_index = match_index[:len(data)//2]

# %%
modify_index[:5]
# Out:
# [283, 868, 1321, 1452, 807]

# %%
#Create a new dataframe df to store the modified data
df = data.loc[modify_index]

# %%
data.columns
# Out:
# Index(['player1', 'player2', 'best_of', 'elo_match_win_rate',
#        'elo_frame_win_rate', 'p1_matches_played', 'p1_matches_won',
#        'p1_frames_played', 'p1_frames_won', 'p2_matches_played',
#        'p2_matches_won', 'p2_frames_played', 'p2_frames_won',
#        'p1_frames_played_1_year', 'p1_frames_won_1_year',
#        'p1_frames_played_3_years', 'p1_frames_won_3_years',
#        'p2_frames_played_1_year', 'p2_frames_won_1_year',
#        'p2_frames_played_3_years', 'p2_frames_won_3_years', 'match_result',
#        'win_percentage'],
#       dtype='object')

# %%
#Exchange the stats of player1 and player2
df['player1'], df['player2'] = df['player2'], df['player1']
df['elo_match_win_rate'], df['elo_frame_win_rate'] = 1-df['elo_match_win_rate'], 1-df['elo_frame_win_rate']
df['p1_matches_played'], df['p1_matches_won'], df['p2_matches_played'], df['p2_matches_won'] = df['p2_matches_played'], df['p2_matches_won'], df['p1_matches_played'], df['p1_matches_won']
df['p1_frames_played'], df['p1_frames_won'], df['p2_frames_played'], df['p2_frames_won'] = df['p2_frames_played'], df['p2_frames_won'], df['p1_frames_played'], df['p1_frames_won']
df['p1_frames_played_1_year'], df['p1_frames_won_1_year'], df['p2_frames_played_1_year'], df['p2_frames_won_1_year'] = df['p2_frames_played_1_year'], df['p2_frames_won_1_year'], df['p1_frames_played_1_year'], df['p1_frames_won_1_year']
df['p1_frames_played_3_years'], df['p1_frames_won_3_years'], df['p2_frames_played_3_years'], df['p2_frames_won_3_years'] = df['p2_frames_played_3_years'], df['p2_frames_won_3_years'], df['p1_frames_played_3_years'], df['p1_frames_won_3_years']

df['match_result'] = 1
df['win_percentage'] = 1 - df['win_percentage']

# %%
data.loc[modify_index] = df

# %%
data.head()
# Out:
#                  player1           player2  best_of  elo_match_win_rate  \
# 0           Long Zehuang     Haydon Pinhey        7            0.719210
# 1          Andrew Pagett       Wang Yuchen        7            0.500000
# 2            Ben Mertens  Daniel Womersley        7            0.699444
# 3            Jimmy White     Paul Deaville        7            0.561265
# 4  Alexander Ursenbacher   Mostafa Dorgham        7            0.821305
#
#    elo_frame_win_rate  p1_matches_played  p1_matches_won  p1_frames_played  \
# 0            0.604679                 78              39               443
# 1            0.500000                352             153              2250
# 2            0.594476                107              50               642
# 3            0.528095               1577             844             13093
# 4            0.663180                286             129              1728
#
#    p1_frames_won  p2_matches_played  ...  p1_frames_played_1_year  \
# 0            225                115  ...                      178
# 1           1055                100  ...                      144
# 2            322                109  ...                      136
# 3           6755                 32  ...                       85
# 4            829                 25  ...                      113
#
#    p1_frames_won_1_year  p1_frames_played_3_years  p1_frames_won_3_years  \
# 0                    99                       284                    147
# 1                    65                       417                    170
# 2                    67                       471                    240
# 3                    31                       384                    153
# 4                    56                       400                    196
#
#    p2_frames_played_1_year  p2_frames_won_1_year  p2_frames_played_3_years  \
# 0                      121                    57                       347
# 1                       74                    38                       158
# 2                       86                    40                       180
# 3                       97                    51                       126
# 4                      108                    41                       154
#
#    p2_frames_won_3_years  match_result  win_percentage
# 0                    168           0.0        0.571429
# 1                     89           1.0        0.200000
# 2                     89           1.0        0.200000
# 3                     66           0.0        0.571429
# 4                     53           0.0        0.800000
#
# [5 rows x 23 columns]

# %%
data.to_csv('match_data_20_tourns_modified.csv', index=False)
