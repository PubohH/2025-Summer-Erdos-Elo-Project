# %% [markdown]
# In the match data generated in data_generation.ipynb, player1 is always the winner. For the purpose of future data exploration and modeling, we exchange player1 and player2 for half of the matches and save it in another csv file.

# %%
import pandas as pd
import numpy as np
import random

# %%
data = pd.read_csv('match_data_50_tourns.csv')

# %%
data.head()
# Out:
#           player1                    player2  best_of  player1_elo  \
# 0      Cao Yupeng                  Jiang Jun        9         1411
# 1    Zhou Yuelong  Siripaporn Nuanthakhamjan        9         1384
# 2         Wu Yize               Allan Taylor        9         1342
# 3  Ben Woollaston               Oliver Brown        9         1412
# 4   Mark Williams              Andres Petrov        9         1611
#
#    player2_elo  elo_match_win_rate  elo_frame_win_rate  p1_matches_played  \
# 0         1044            0.918016            0.714532                341
# 1          965            0.943119            0.740295                459
# 2         1237            0.656987            0.565251                 78
# 3         1146            0.845318            0.660383                803
# 4         1045            0.982235            0.804553               1751
#
#    p1_matches_won  p1_frames_played  ...  p1_frames_won_3_years  \
# 0             179              2302  ...                    242
# 1             272              2879  ...                    430
# 2              37               552  ...                    215
# 3             454              5053  ...                    282
# 4            1151             12775  ...                    649
#
#    p2_frames_played_1_year  p2_frames_won_1_year  p2_frames_played_3_years  \
# 0                       32                    17                        32
# 1                       23                     4                        23
# 2                      101                    49                       336
# 3                       91                    35                       235
# 4                       79                    25                       167
#
#    p2_frames_won_3_years  score1  score2  match_result  win_percentage  \
# 0                     17       5       0           0.0        1.000000
# 1                      4       5       2           0.0        0.714286
# 2                    147       5       3           0.0        0.625000
# 3                     97       5       2           0.0        0.714286
# 4                     61       5       2           0.0        0.714286
#
#    tournament_id
# 0           5808
# 1           5808
# 2           5808
# 3           5808
# 4           5808
#
# [5 rows x 28 columns]

# %%
row = data.loc[0]

# %%
#We use random.shuffle to choose the indices of matches we want to modify.
match_index = list(range(len(data)))
random.shuffle(match_index)
modify_index = match_index[:len(data)//2]

# %%
modify_index[:5]
# Out:
# [2909, 2144, 844, 3967, 4733]

# %%
data.loc[modify_index].head(5)
# Out:
#                  player1                 player2  best_of  player1_elo  \
# 2909        Farakh Ajaib        Haitham Al Mahri        7         1153
# 2144  Muhammad Umar Khan  Mohammad Reza Pishvari        7          993
# 844         Oliver Lines              Ma Hailong        1         1355
# 3967         Ding Junhui               Jiang Jun        9         1541
# 4733        Zhao Hanyang        Thor Chuan Leong        7          991
#
#       player2_elo  elo_match_win_rate  elo_frame_win_rate  p1_matches_played  \
# 2909         1000            0.699444            0.594476                153
# 2144          999            0.491797            0.496250                  1
# 844          1077            0.667078            0.667078                358
# 3967         1266            0.853217            0.665411               1020
# 4733         1243            0.195762            0.347511                 10
#
#       p1_matches_won  p1_frames_played  ...  p1_frames_won_3_years  \
# 2909              66               832  ...                    136
# 2144               0                 6  ...                      2
# 844              171              2160  ...                    263
# 3967             678              7848  ...                    420
# 4733               4                54  ...                     14
#
#       p2_frames_played_1_year  p2_frames_won_1_year  p2_frames_played_3_years  \
# 2909                        0                     0                         0
# 2144                       12                     6                        12
# 844                       134                    55                       134
# 3967                       20                    12                       348
# 4733                       74                    37                       375
#
#       p2_frames_won_3_years  score1  score2  match_result  win_percentage  \
# 2909                      0       4       0           0.0        1.000000
# 2144                      6       4       1           0.0        0.800000
# 844                      55       1       0           0.0        1.000000
# 3967                    170       5       1           0.0        0.833333
# 4733                    185       4       3           0.0        0.571429
#
#       tournament_id
# 2909           6265
# 2144           6183
# 844            5875
# 3967           6445
# 4733           6786
#
# [5 rows x 28 columns]

# %%
#Create a new dataframe df to store the modified data
df = data.loc[modify_index]

# %%
data.columns
# Out:
# Index(['player1', 'player2', 'best_of', 'player1_elo', 'player2_elo',
#        'elo_match_win_rate', 'elo_frame_win_rate', 'p1_matches_played',
#        'p1_matches_won', 'p1_frames_played', 'p1_frames_won',
#        'p2_matches_played', 'p2_matches_won', 'p2_frames_played',
#        'p2_frames_won', 'p1_frames_played_1_year', 'p1_frames_won_1_year',
#        'p1_frames_played_3_years', 'p1_frames_won_3_years',
#        'p2_frames_played_1_year', 'p2_frames_won_1_year',
#        'p2_frames_played_3_years', 'p2_frames_won_3_years', 'score1', 'score2',
#        'match_result', 'win_percentage', 'tournament_id'],
#       dtype='object')

# %%
#Exchange the stats of player1 and player2
df['player1'], df['player2'] = df['player2'], df['player1']
df['player1_elo'], df['player2_elo'] = df['player2_elo'], df['player1_elo']
df['elo_match_win_rate'], df['elo_frame_win_rate'] = 1-df['elo_match_win_rate'], 1-df['elo_frame_win_rate']
df['p1_matches_played'], df['p1_matches_won'], df['p2_matches_played'], df['p2_matches_won'] = df['p2_matches_played'], df['p2_matches_won'], df['p1_matches_played'], df['p1_matches_won']
df['p1_frames_played'], df['p1_frames_won'], df['p2_frames_played'], df['p2_frames_won'] = df['p2_frames_played'], df['p2_frames_won'], df['p1_frames_played'], df['p1_frames_won']
df['p1_frames_played_1_year'], df['p1_frames_won_1_year'], df['p2_frames_played_1_year'], df['p2_frames_won_1_year'] = df['p2_frames_played_1_year'], df['p2_frames_won_1_year'], df['p1_frames_played_1_year'], df['p1_frames_won_1_year']
df['p1_frames_played_3_years'], df['p1_frames_won_3_years'], df['p2_frames_played_3_years'], df['p2_frames_won_3_years'] = df['p2_frames_played_3_years'], df['p2_frames_won_3_years'], df['p1_frames_played_3_years'], df['p1_frames_won_3_years']
df['score1'], df['score2'] = df['score2'], df['score1']
df['match_result'] = 1
df['win_percentage'] = 1 - df['win_percentage']

# %%
data.loc[modify_index] = df

# %%
data.head()
# Out:
#                      player1        player2  best_of  player1_elo  \
# 0                 Cao Yupeng      Jiang Jun        9         1411
# 1  Siripaporn Nuanthakhamjan   Zhou Yuelong        9          965
# 2                    Wu Yize   Allan Taylor        9         1342
# 3             Ben Woollaston   Oliver Brown        9         1412
# 4              Andres Petrov  Mark Williams        9         1045
#
#    player2_elo  elo_match_win_rate  elo_frame_win_rate  p1_matches_played  \
# 0         1044            0.918016            0.714532                341
# 1         1384            0.056881            0.259705                  3
# 2         1237            0.656987            0.565251                 78
# 3         1146            0.845318            0.660383                803
# 4         1611            0.017765            0.195447                 51
#
#    p1_matches_won  p1_frames_played  ...  p1_frames_won_3_years  \
# 0             179              2302  ...                    242
# 1               0                23  ...                      4
# 2              37               552  ...                    215
# 3             454              5053  ...                    282
# 4              18               304  ...                     61
#
#    p2_frames_played_1_year  p2_frames_won_1_year  p2_frames_played_3_years  \
# 0                       32                    17                        32
# 1                      245                   118                       808
# 2                      101                    49                       336
# 3                       91                    35                       235
# 4                      281                   170                      1112
#
#    p2_frames_won_3_years  score1  score2  match_result  win_percentage  \
# 0                     17       5       0           0.0        1.000000
# 1                    430       2       5           1.0        0.285714
# 2                    147       5       3           0.0        0.625000
# 3                     97       5       2           0.0        0.714286
# 4                    649       2       5           1.0        0.285714
#
#    tournament_id
# 0           5808
# 1           5808
# 2           5808
# 3           5808
# 4           5808
#
# [5 rows x 28 columns]

# %%
data.loc[modify_index].head(5)
# Out:
#                      player1             player2  best_of  player1_elo  \
# 2909        Haitham Al Mahri        Farakh Ajaib        7         1000
# 2144  Mohammad Reza Pishvari  Muhammad Umar Khan        7          999
# 844               Ma Hailong        Oliver Lines        1         1077
# 3967               Jiang Jun         Ding Junhui        9         1266
# 4733        Thor Chuan Leong        Zhao Hanyang        7         1243
#
#       player2_elo  elo_match_win_rate  elo_frame_win_rate  p1_matches_played  \
# 2909         1153            0.300556            0.405524                  0
# 2144          993            0.508203            0.503750                  2
# 844          1355            0.332922            0.332922                 20
# 3967         1541            0.146783            0.334589                 50
# 4733          991            0.804238            0.652489                208
#
#       p1_matches_won  p1_frames_played  ...  p1_frames_won_3_years  \
# 2909               0                 0  ...                      0
# 2144               1                12  ...                      6
# 844                6               134  ...                     55
# 3967              22               348  ...                    170
# 4733              78              1318  ...                    185
#
#       p2_frames_played_1_year  p2_frames_won_1_year  p2_frames_played_3_years  \
# 2909                       74                    43                       280
# 2144                        6                     2                         6
# 844                       222                   116                       520
# 3967                        0                     0                       762
# 4733                       15                    10                        27
#
#       p2_frames_won_3_years  score1  score2  match_result  win_percentage  \
# 2909                    136       0       4           1.0        0.000000
# 2144                      2       1       4           1.0        0.200000
# 844                     263       0       1           1.0        0.000000
# 3967                    420       1       5           1.0        0.166667
# 4733                     14       3       4           1.0        0.428571
#
#       tournament_id
# 2909           6265
# 2144           6183
# 844            5875
# 3967           6445
# 4733           6786
#
# [5 rows x 28 columns]

# %%
data.to_csv('match_data_50_tourns_modified.csv', index=False)
