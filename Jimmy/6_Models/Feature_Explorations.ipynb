# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/tliu/Desktop/Erdos Project/3_Player_Data_Generation/match_data_20_tourns_modified.csv')
data.head()
# Out:
#                  player1           player2  best_of  player1_elo  player2_elo  \
# 0           Long Zehuang     Haydon Pinhey        7         1328         1158
# 1            Wang Yuchen     Andrew Pagett        7         1162         1162
# 2            Ben Mertens  Daniel Womersley        7         1262         1109
# 3          Paul Deaville       Jimmy White        7         1096         1141
# 4  Alexander Ursenbacher   Mostafa Dorgham        7         1302         1031
#
#    elo_match_win_rate  elo_frame_win_rate  p1_matches_played  p1_matches_won  \
# 0            0.719210            0.604679                 78              39
# 1            0.500000            0.500000                100              37
# 2            0.699444            0.594476                107              50
# 3            0.438735            0.471905                 32              17
# 4            0.821305            0.663180                286             129
#
#    p1_frames_played  ...  p1_frames_played_3_years  p1_frames_won_3_years  \
# 0               443  ...                       284                    147
# 1               626  ...                       158                     89
# 2               642  ...                       471                    240
# 3               158  ...                       126                     66
# 4              1728  ...                       400                    196
#
#    p2_frames_played_1_year  p2_frames_won_1_year  p2_frames_played_3_years  \
# 0                      121                    57                       347
# 1                      144                    65                       417
# 2                       86                    40                       180
# 3                       85                    31                       384
# 4                      108                    41                       154
#
#    p2_frames_won_3_years  score1  score2  match_result  win_percentage
# 0                    168       4       3           0.0        0.571429
# 1                    170       4       1           0.0        0.800000
# 2                     89       1       4           1.0        0.200000
# 3                    153       3       4           1.0        0.428571
# 4                     53       4       1           0.0        0.800000
#
# [5 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['player1', 'player2', 'best_of', 'player1_elo', 'player2_elo',
#        'elo_match_win_rate', 'elo_frame_win_rate', 'p1_matches_played',
#        'p1_matches_won', 'p1_frames_played', 'p1_frames_won',
#        'p2_matches_played', 'p2_matches_won', 'p2_frames_played',
#        'p2_frames_won', 'p1_frames_played_1_year', 'p1_frames_won_1_year',
#        'p1_frames_played_3_years', 'p1_frames_won_3_years',
#        'p2_frames_played_1_year', 'p2_frames_won_1_year',
#        'p2_frames_played_3_years', 'p2_frames_won_3_years', 'score1', 'score2',
#        'match_result', 'win_percentage'],
#       dtype='object')

# %%
X_data = data.drop(['player1', 'player2', 'score1', 'score2', 'match_result', 'win_percentage'], axis = 1)
y = data.match_result

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_data)

pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_scaled)

# %%
coefficients = pca.components_
coefficients
# Out:
# array([[ 0.04701211,  0.2583186 ,  0.25379353,  0.00245973,  0.00455696,
#          0.23758482,  0.23805186,  0.23346497,  0.23398158,  0.23462858,
#          0.23397646,  0.23058678,  0.23026613,  0.19014191,  0.19287461,
#          0.26947334,  0.26757755,  0.18715811,  0.19017796,  0.26483686,
#          0.26337049],
#        [ 0.00290406,  0.16645569, -0.185791  ,  0.38572744,  0.38977721,
#          0.22115573,  0.2237717 ,  0.2199162 ,  0.22159218, -0.22974355,
#         -0.23212598, -0.22925624, -0.23030491,  0.14571837,  0.15590508,
#          0.18625531,  0.19173017, -0.12026944, -0.13116303, -0.19693568,
#         -0.20222949],
#        [-0.08982567, -0.04687401, -0.03083678, -0.01843821, -0.01854283,
#         -0.17387365, -0.17259782, -0.1787176 , -0.17786097, -0.17605944,
#         -0.17779417, -0.18153863, -0.18212128,  0.42304737,  0.40314712,
#          0.02746176,  0.01778778,  0.45058474,  0.43282794,  0.0422738 ,
#          0.03240122]])

# %%
for coeff in coefficients:
    sorted_indices = np.argsort(np.abs(coeff))
    print(X_data.columns[sorted_indices])
# Out:
# Index(['elo_match_win_rate', 'elo_frame_win_rate', 'best_of',
#        'p2_frames_played_1_year', 'p1_frames_played_1_year',
#        'p2_frames_won_1_year', 'p1_frames_won_1_year', 'p2_frames_won',
#        'p2_frames_played', 'p1_frames_played', 'p2_matches_won',
#        'p1_frames_won', 'p2_matches_played', 'p1_matches_played',
#        'p1_matches_won', 'player2_elo', 'player1_elo', 'p2_frames_won_3_years',
#        'p2_frames_played_3_years', 'p1_frames_won_3_years',
#        'p1_frames_played_3_years'],
#       dtype='object')
# Index(['best_of', 'p2_frames_played_1_year', 'p2_frames_won_1_year',
#        'p1_frames_played_1_year', 'p1_frames_won_1_year', 'player1_elo',
#        'player2_elo', 'p1_frames_played_3_years', 'p1_frames_won_3_years',
#        'p2_frames_played_3_years', 'p2_frames_won_3_years', 'p1_frames_played',
#        'p1_matches_played', 'p1_frames_won', 'p1_matches_won',
#        'p2_frames_played', 'p2_matches_played', 'p2_frames_won',
#        'p2_matches_won', 'elo_match_win_rate', 'elo_frame_win_rate'],
#       dtype='object')
# Index(['p1_frames_won_3_years', 'elo_match_win_rate', 'elo_frame_win_rate',
#        'p1_frames_played_3_years', 'player2_elo', 'p2_frames_won_3_years',
#        'p2_frames_played_3_years', 'player1_elo', 'best_of', 'p1_matches_won',
#        'p1_matches_played', 'p2_matches_played', 'p2_matches_won',
#        'p1_frames_won', 'p1_frames_played', 'p2_frames_played',
#        'p2_frames_won', 'p1_frames_won_1_year', 'p1_frames_played_1_year',
#        'p2_frames_won_1_year', 'p2_frames_played_1_year'],
#       dtype='object')
