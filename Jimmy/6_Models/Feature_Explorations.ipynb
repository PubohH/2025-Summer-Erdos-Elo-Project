# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/tliu/Desktop/Erdos Project/3_Player_Data_Generation/match_data_50_tourns_modified.csv')
data.head()
# Out:
#                      player1        player2  best_of  player1_elo  \
# 0                 Cao Yupeng      Jiang Jun        9         1411
# 1  Siripaporn Nuanthakhamjan   Zhou Yuelong        9          965
# 2                    Wu Yize   Allan Taylor        9         1342
# 3             Ben Woollaston   Oliver Brown        9         1412
# 4              Andres Petrov  Mark Williams        9         1045
#
#    player2_elo  elo_match_win_rate  elo_frame_win_rate  p1_matches_played  \
# 0         1044            0.918016            0.714532                341
# 1         1384            0.056881            0.259705                  3
# 2         1237            0.656987            0.565251                 78
# 3         1146            0.845318            0.660383                803
# 4         1611            0.017765            0.195447                 51
#
#    p1_matches_won  p1_frames_played  ...  p1_frames_played_3_years  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5058 entries, 0 to 5057
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   player1                   5058 non-null   object
#  1   player2                   5058 non-null   object
#  2   best_of                   5058 non-null   int64
#  3   player1_elo               5058 non-null   int64
#  4   player2_elo               5058 non-null   int64
#  5   elo_match_win_rate        5058 non-null   float64
#  6   elo_frame_win_rate        5058 non-null   float64
#  7   p1_matches_played         5058 non-null   int64
#  8   p1_matches_won            5058 non-null   int64
#  9   p1_frames_played          5058 non-null   int64
#  10  p1_frames_won             5058 non-null   int64
#  11  p2_matches_played         5058 non-null   int64
#  12  p2_matches_won            5058 non-null   int64
#  13  p2_frames_played          5058 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['player1', 'player2', 'best_of', 'player1_elo', 'player2_elo',
#        'elo_match_win_rate', 'elo_frame_win_rate', 'p1_matches_played',
#        'p1_matches_won', 'p1_frames_played', 'p1_frames_won',
#        'p2_matches_played', 'p2_matches_won', 'p2_frames_played',
#        'p2_frames_won', 'p1_frames_played_1_year', 'p1_frames_won_1_year',
#        'p1_frames_played_3_years', 'p1_frames_won_3_years',
#        'p2_frames_played_1_year', 'p2_frames_won_1_year',
#        'p2_frames_played_3_years', 'p2_frames_won_3_years', 'score1', 'score2',
#        'match_result', 'win_percentage'],
#       dtype='object')

# %%
X_data = data.drop(['player1', 'player2', 'score1', 'score2', 'match_result', 'win_percentage'], axis = 1)
y = data.match_result

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_data)

pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_scaled)

# %%
coefficients = pca.components_
coefficients
# Out:
# array([[ 0.05202412,  0.25458309,  0.25150521,  0.00282822,  0.00404926,
#          0.23502707,  0.2345598 ,  0.2304482 ,  0.23031982,  0.23547452,
#          0.23560705,  0.23149657,  0.23157982,  0.20060165,  0.20238804,
#          0.26403923,  0.26147001,  0.19704014,  0.2004056 ,  0.26180115,
#          0.26038619],
#        [-0.00479198,  0.18338075, -0.1891457 ,  0.36463099,  0.3707707 ,
#          0.22389822,  0.22768398,  0.22284164,  0.22468681, -0.22162232,
#         -0.22348377, -0.2201833 , -0.22097489,  0.14259228,  0.15421321,
#          0.20075821,  0.20623362, -0.15137657, -0.16054785, -0.20544615,
#         -0.20931255],
#        [-0.06676044, -0.02855444, -0.02380665, -0.0074583 , -0.00529684,
#         -0.17924187, -0.17946024, -0.18595168, -0.18567894, -0.19424923,
#         -0.19533379, -0.20208248, -0.20221408,  0.42622868,  0.40787782,
#          0.04073971,  0.03209186,  0.42784859,  0.4082826 ,  0.04058633,
#          0.03085199]])

# %%
for coeff in coefficients:
    sorted_indices = np.argsort(np.abs(coeff))
    print(X_data.columns[sorted_indices])
# Out:
# Index(['elo_match_win_rate', 'elo_frame_win_rate', 'best_of',
#        'p2_frames_played_1_year', 'p2_frames_won_1_year',
#        'p1_frames_played_1_year', 'p1_frames_won_1_year', 'p1_frames_won',
#        'p1_frames_played', 'p2_frames_played', 'p2_frames_won',
#        'p1_matches_won', 'p1_matches_played', 'p2_matches_played',
#        'p2_matches_won', 'player2_elo', 'player1_elo', 'p2_frames_won_3_years',
#        'p1_frames_won_3_years', 'p2_frames_played_3_years',
#        'p1_frames_played_3_years'],
#       dtype='object')
# Index(['best_of', 'p1_frames_played_1_year', 'p2_frames_played_1_year',
#        'p1_frames_won_1_year', 'p2_frames_won_1_year', 'player1_elo',
#        'player2_elo', 'p1_frames_played_3_years', 'p2_frames_played_3_years',
#        'p1_frames_won_3_years', 'p2_frames_won_3_years', 'p2_frames_played',
#        'p2_frames_won', 'p2_matches_played', 'p1_frames_played',
#        'p2_matches_won', 'p1_matches_played', 'p1_frames_won',
# ...
